# %% [markdown]
# # GSM8

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def run_pal_lang(lang_code='en', n_examples=1319, model='gpt-3.5-turbo'):
    lang = f"--lang {lang_code}"
    n_examples = f"--n_examples {n_examples}"
    model = f"--model {model}"

    
    params = f" {lang} {n_examples} {model}"
    
    # !python gsm_eval.py {params}

# %% [markdown]
# ## gpt-3.5

# %% [markdown]
# ### English Acc 0.78089

# %%
run_pal_lang('en')
# Out:
# Traceback (most recent call last):
#   File "/Users/juglardiaz-zamora/Projects/multilingual-augmented-llm/pal/scripts/gsm_eval.py", line 25, in <module>
#     from pal import interface
#   File "/Users/juglardiaz-zamora/Projects/multilingual-augmented-llm/pal/scripts/../pal/__init__.py", line 16, in <module>
#     from .core import interface, runtime
#   File "/Users/juglardiaz-zamora/Projects/multilingual-augmented-llm/pal/scripts/../pal/core/interface.py", line 24, in <module>
#     from ....llms import call_gpt, call_chat_gpt
# ImportError: attempted relative import beyond top-level package

# %%
run_pal_lang('en')
# Out:
# ...
#   7%|██▌                                    | 88/1319 [09:50<4:05:10, 11.95s/it]local variable 'harald_copies' referenced before assignment
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#  11%|████▏                                 | 144/1319 [15:13<1:50:17,  5.63s/it]name 'total' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#  14%|█████▎                                | 184/1319 [20:13<2:05:59,  6.66s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### Spanish Acc 0.71417

# %%
run_pal_lang('es')
# Out:
#   0%|                                        | 1/1319 [00:07<2:43:22,  7.44s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▏                                       | 8/1319 [00:49<2:31:03,  6.91s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   2%|▊                                      | 27/1319 [03:16<2:34:29,  7.17s/it]name 'porciones_por_dia' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### Portuguese Acc 0.6557

# %%
run_pal_lang('pt')
# Out:
#   1%|▏                                       | 8/1319 [00:46<2:12:02,  6.04s/it]expected an indented block after 'if' statement on line 13 (<string>, line 13)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▌                                      | 19/1319 [02:23<2:27:20,  6.80s/it]division by zero
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   6%|██▏                                    | 74/1319 [07:25<1:45:50,  5.10s/it]name 'ganhos_beg' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### Italian Acc 0.6451

# %%
run_pal_lang('it')
# Out:
#   0%|                                        | 1/1319 [00:10<3:46:37, 10.32s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   0%|                                        | 4/1319 [00:23<1:55:54,  5.29s/it]name 'tazze_mang' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▏                                       | 8/1319 [00:58<2:39:02,  7.28s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### French Acc  0.6611

# %%
run_pal_lang('fr')
# Out:
# ...
#   1%|▏                                       | 8/1319 [00:34<1:38:52,  4.52s/it]name 'distance_totale' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   2%|▌                                      | 21/1319 [01:35<1:39:55,  4.62s/it]unterminated string literal (detected at line 6) (<string>, line 6)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   3%|█▏                                     | 41/1319 [02:55<1:24:02,  3.95s/it]name 'distance' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ## PALM text Bison

# %% [markdown]
# ### EN 0.61

# %%
run_pal_lang(lang_code='en', model = "text-bison@001")
# Out:
# ...
#   3%|█                                        | 36/1319 [01:48<51:18,  2.40s/it]name 'yogurts_per_month_on' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   4%|█▋                                       | 53/1319 [02:36<51:49,  2.46s/it]name 'total' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   6%|██▎                                      | 74/1319 [03:37<50:12,  2.42s/it]name 'petunia' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### ES 0.57

# %%
run_pal_lang(lang_code='es', model = "text-bison@001")
# Out:
#   1%|▏                                       | 8/1319 [00:23<1:04:28,  2.95s/it]name 'distancia_recorr' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   2%|▊                                        | 26/1319 [01:16<54:55,  2.55s/it]name 'precio' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   3%|█▎                                       | 41/1319 [01:57<56:23,  2.65s/it]name 'distancia_' is not defined
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ## PALM chat Bison

# %% [markdown]
# ### EN 0.477

# %%
run_pal_lang(lang_code='en', model = "chat-bison@001")
# Out:
#   0%|▏                                         | 4/1319 [00:09<52:01,  2.37s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▏                                         | 7/1319 [00:17<56:12,  2.57s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▎                                         | 8/1319 [00:20<57:14,  2.62s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### ES 0.51

# %%
run_pal_lang(lang_code='es', model = "chat-bison@001")
# Out:
#   0%|                                        | 1/1319 [00:02<1:02:33,  2.85s/it]invalid character '¿' (U+00BF) (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   1%|▏                                         | 7/1319 [00:17<57:10,  2.61s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   1%|▎                                         | 8/1319 [00:20<57:22,  2.63s/it]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ## PALM codechat Bison

# %% [markdown]
# ### EN

# %%
run_pal_lang(lang_code='en', model = "codechat-bison@001")
# Out:
#   0%|                                                  | 0/1319 [00:00<?, ?it/s]invalid syntax (<string>, line 2)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   0%|                                        | 1/1319 [00:04<1:37:37,  4.44s/it]invalid syntax (<string>, line 2)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   0%|                                        | 2/1319 [00:07<1:18:07,  3.56s/it]invalid syntax (<string>, line 2)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...

# %% [markdown]
# ### ES

# %%
run_pal_lang(lang_code='es', model = "codechat-bison@001")

# %% [markdown]
# ## PALM code Bison

# %% [markdown]
# ### EN

# %%
run_pal_lang(lang_code='en', model = "code-bison@001")
# Out:
#   0%|                                                  | 0/1319 [00:00<?, ?it/s]invalid syntax (<string>, line 1)
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
#   0%|                                        | 1/1319 [00:04<1:39:54,  4.55s/it]solution() missing 2 required positional arguments: 'blue_fiber' and 'white_fiber'
# No results was produced. A common reason is that the generated code snippet is not valid or did not return any results.
# float() argument must be a string or a real number, not 'NoneType'
# ...
#   0%|                                        | 2/1319 [00:08<1:34:04,  4.29s/it]
# Traceback (most recent call last):
#   File "/Users/juglardiaz-zamora/Projects/multilingual-augmented-llm/pal/scripts/gsm_eval.py", line 82, in <module>
#     ans = itf.run(math_prompts.dict_prompts[args.lang]['MATH_PROMPT'].format(
# ...

# %% [markdown]
# ### ES

# %%
run_pal_lang(lang_code='es', model = "code-bison@001")
