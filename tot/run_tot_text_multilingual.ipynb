# %%
def run_tot_lang(lang_code='en', model='gpt-3.5-turbo'):
    task = "--task text"
    file = f"--task_file_path data_100_random_text_{lang_code}.txt"
    ini = "--task_start_index 0"
    end = "--task_end_index 100"
    prompt_sample = "--prompt_sample cot"
    gen_sample = "--n_generate_sample 3"
    eva_sample = "--n_evaluate_sample 3"
    sel_sample = "--n_select_sample 1"
    method_generate = "--method_generate sample"
    method_evaluate = "--method_evaluate vote"
    method_select = "--method_select greedy"
    temp = "--temperature 0.7"
    lang = f"--lang {lang_code}"
    model = f"--backend {model}"


    params = f"{task} {file} {ini} {end} {prompt_sample} {gen_sample} {eva_sample} {sel_sample} {method_generate} {method_evaluate} {method_select} {temp} {lang} {model}"
    
    # !python run.py {params}

# %% [markdown]
# # ToT Baseline Dataset Text English, Metric 6.848

# %%
run_tot_lang('en')
# Out:
# Namespace(backend='gpt-3.5-turbo', temperature=0.7, lang='en', task='text', task_file_path='data_100_random_text_en.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 accs [7.8] cnt_avg 7.8 avg_so_far 7.8
#
# 2 accs [8.0] cnt_avg 15.8 avg_so_far 7.9
#
# ...

# %% [markdown]
# # ToT Dataset Text Spanish, Metric 7.779

# %%
run_tot_lang('es')
# Out:
# Namespace(backend='gpt-3.5-turbo', temperature=0.7, lang='es', task='text', task_file_path='data_100_random_text_es.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 accs [8.0] cnt_avg 8.0 avg_so_far 8.0
#
# 2 accs [8.333333333333334] cnt_avg 16.333333333333336 avg_so_far 8.166666666666668
#
# 3 accs [8.0] cnt_avg 24.333333333333336 avg_so_far 8.111111111111112
#
# 4 accs [7.666666666666667] cnt_avg 32.0 avg_so_far 8.0
#
# 5 accs [8.0] cnt_avg 40.0 avg_so_far 8.0
#
# 6 accs [9.0] cnt_avg 49.0 avg_so_far 8.166666666666666
#
# 7 accs [7.666666666666667] cnt_avg 56.666666666666664 avg_so_far 8.095238095238095
#
# 8 accs [8.666666666666666] cnt_avg 65.33333333333333 avg_so_far 8.166666666666666
#
# 9 accs [8.0] cnt_avg 73.33333333333333 avg_so_far 8.148148148148147
#
# ...

# %% [markdown]
# # ToT Baseline Dataset Text Portuguese, Metric 7.155

# %%
run_tot_lang('pt')
# Out:
# Namespace(backend='gpt-3.5-turbo', temperature=0.7, lang='pt', task='text', task_file_path='data_100_random_text_pt.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 accs [8.0] cnt_avg 8.0 avg_so_far 8.0
#
# 2 accs [7.333333333333333] cnt_avg 15.333333333333332 avg_so_far 7.666666666666666
#
# 3 accs [9.0] cnt_avg 24.333333333333332 avg_so_far 8.11111111111111
#
# 4 accs [8.333333333333334] cnt_avg 32.666666666666664 avg_so_far 8.166666666666666
#
# 5 accs [8.333333333333334] cnt_avg 41.0 avg_so_far 8.2
#
# 6 accs [8.666666666666666] cnt_avg 49.666666666666664 avg_so_far 8.277777777777777
#
# 7 accs [8.0] cnt_avg 57.666666666666664 avg_so_far 8.238095238095237
#
# 8 accs [8.666666666666666] cnt_avg 66.33333333333333 avg_so_far 8.291666666666666
#
# ...

# %% [markdown]
# # ToT Baseline Dataset Text French, Metric 4.80

# %%
run_tot_lang('fr')
# Out:
# Namespace(backend='gpt-3.5-turbo', temperature=0.7, lang='fr', task='text', task_file_path='data_100_random_text_fr.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 scores [[1, 2, 2]] accs [1.6666666666666667] cnt_avg 1.6666666666666667 avg_so_far 1.6666666666666667
#
# 2 scores [[7, 7, 7]] accs [7.0] cnt_avg 8.666666666666666 avg_so_far 4.333333333333333
#
# 3 scores [[3, 5, 7]] accs [5.0] cnt_avg 13.666666666666666 avg_so_far 4.555555555555555
#
# 4 scores [[8, 6, 6]] accs [6.666666666666667] cnt_avg 20.333333333333332 avg_so_far 5.083333333333333
#
# 5 scores [[7, 3, 7]] accs [5.666666666666667] cnt_avg 26.0 avg_so_far 5.2
#
# 6 scores [[8, 8, 7]] accs [7.666666666666667] cnt_avg 33.666666666666664 avg_so_far 5.611111111111111
#
# ...

# %% [markdown]
# # ToT Baseline Dataset Text Italian, Metric 6.92

# %%
run_tot_lang('it')
# Out:
# Namespace(backend='gpt-3.5-turbo', temperature=0.7, lang='it', task='text', task_file_path='data_100_random_text_it.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 scores [[6, 5, 6]] accs [5.666666666666667] cnt_avg 5.666666666666667 avg_so_far 5.666666666666667
#
# 2 scores [[8, 8, 10]] accs [8.666666666666666] cnt_avg 14.333333333333332 avg_so_far 7.166666666666666
#
# 3 scores [[8, 7, 8]] accs [7.666666666666667] cnt_avg 22.0 avg_so_far 7.333333333333333
#
# 4 scores [[8, 8, 7]] accs [7.666666666666667] cnt_avg 29.666666666666668 avg_so_far 7.416666666666667
#
# 5 scores [[10, 8, 10]] accs [9.333333333333334] cnt_avg 39.0 avg_so_far 7.8
#
# 6 scores [[8, 7, 9]] accs [8.0] cnt_avg 47.0 avg_so_far 7.833333333333333
#
# ...

# %% [markdown]
# 8.62 0.98

# %%
run_tot_lang('en', 'text-bison@001')
# Out:
# Namespace(backend='text-bison@001', temperature=0.7, lang='en', task='text', task_file_path='data_100_random_text_en.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 scores [[7, 10, 9]] accs [8.666666666666666] cnt_avg 8.666666666666666 avg_so_far 8.666666666666666
#
# ------------------score no match: ['The passage is about how the US president could improve the economy. It is a well-written, coherent paragraph. The author uses evidence to support their claims and provides a clear plan for how the president could improve the economy. Therefore, I would give the passage a coherency score of 9.']
# ...

# %% [markdown]
# 6.1483333333333325 0.9

# %%
run_tot_lang('es', 'text-bison@001')
# Out:
# Namespace(backend='text-bison@001', temperature=0.7, lang='es', task='text', task_file_path='data_100_random_text_es.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# ------------------score no match: ['El pasaje es sobre las diferencias entre la inteligencia humana y artificial. El autor compara la inteligencia humana con la inteligencia artificial y señala las deficiencias de la inteligencia artificial. La puntuación de coherencia del pasaje es 7 porque es bien escrito y hace un buen trabajo al comparar la inteligencia humana y artificial.']
# ------------------score no match: ['El pasaje habla de las diferentes formas de comunicación que tienen los humanos. Este pasaje es coherente y bien escrito, por lo que le doy un 10.']
# 1 scores [[8]] accs [8.0] cnt_avg 8.0 avg_so_far 8.0
#
# ...

# %% [markdown]
# 7.2683333333333335 0.84

# %%
run_tot_lang('en', 'chat-bison@001')
# Out:
# Namespace(backend='chat-bison@001', temperature=0.7, lang='en', task='text', task_file_path='data_100_random_text_en.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# ------------------score no match: ["The passage is about the history of the University of California, Los Angeles (UCLA). It starts with the university's founding in 1919, and then goes on to discuss its growth and development over the years. The passage is well-written and organized, and it provides a comprehensive overview of UCLA's history. I would give it a coherency score of 9."]
# 1 scores [[7, 9]] accs [8.0] cnt_avg 8.0 avg_so_far 8.0
#
# ...

# %% [markdown]
# 7.5616666666666665 0.91

# %%
run_tot_lang('es', 'chat-bison@001')
# Out:
# Namespace(backend='chat-bison@001', temperature=0.7, lang='es', task='text', task_file_path='data_100_random_text_es.txt', task_start_index=0, task_end_index=100, naive_run=False, prompt_sample='cot', method_generate='sample', method_evaluate='vote', method_select='greedy', n_generate_sample=3, n_evaluate_sample=3, n_select_sample=1)
# 1 scores [[9, 9, 9]] accs [9.0] cnt_avg 9.0 avg_so_far 9.0
#
# 2 scores [[9, 7, 8]] accs [8.0] cnt_avg 17.0 avg_so_far 8.5
#
# 3 scores [[9, 9, 7]] accs [8.333333333333334] cnt_avg 25.333333333333336 avg_so_far 8.444444444444445
#
# ...
